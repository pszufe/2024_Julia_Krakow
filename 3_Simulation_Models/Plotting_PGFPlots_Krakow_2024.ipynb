# %%
using DataFrames, Plots, LaTeXStrings, PGFPlotsX
pgfplotsx() # this is a backend for LaTeX plotting
# Out:
# Plots.PGFPlotsXBackend()

# %%
df = DataFrame(y1=rand(5), y2=rand(5).+2)
# Out:
# 5×2 DataFrame
#  Row │ y1        y2
#      │ Float64   Float64
# ─────┼───────────────────
#    1 │ 0.787915  2.80244
#    2 │ 0.841082  2.03177
#    3 │ 0.792257  2.21901
#    4 │ 0.528828  2.94721
#    5 │ 0.764107  2.64177

# %%
labels = names(df)
# Out:
# 2-element Vector{String}:
#  "y1"
#  "y2"

# %%
mx = Matrix(df)
# Out:
# 5×2 Matrix{Float64}:
#  0.787915  2.80244
#  0.841082  2.03177
#  0.792257  2.21901
#  0.528828  2.94721
#  0.764107  2.64177

# %%
p = plot(mx;xlabel=L"\hat{x}", label=permutedims(labels), linewidth=[2 4], ylabel=L"Some $\frac{y}{4}$ value", legend=:left )
#plot!(p, df.y1, label=L"Y_1", linecolor=:blue,linewidth=2)
#plot!(p, df.y2, label=L"Y_2", linecolor=:red,linewidth=3)

# %%
savefig(p,"myplt.tikz")
savefig(p,"myplt.pdf")
# Out:
# "C:\\AAABIBLIOTEKA\\NCN2\\SSC2024\\2024_Julia_Krakow\\3_Simulation_Models\\myplt.pdf"

# %%
latex=raw"""
\documentclass{article}
\usepackage{tikz} 
\usepackage{tikzscale}
\usepackage{pgfplots}
\usetikzlibrary{backgrounds}
\usetikzlibrary{intersections}

\begin{document}
\title{My Research for EC}
\maketitle
\section{Section}
text text text
\begin{figure}
\includegraphics[width=\textwidth]{myplt.tikz}
\caption{My caption}
\end{figure}
\end{document}
"""
open("example.tex","w") do f println(f, latex) end
pwd()
# Out:
# "C:\\AAABIBLIOTEKA\\NCN2\\SSC2024\\2024_Julia_Krakow\\3_Simulation_Models"

# %%
df
# Out:
# 5×2 DataFrame
#  Row │ y1        y2
#      │ Float64   Float64
# ─────┼───────────────────
#    1 │ 0.787915  2.80244
#    2 │ 0.841082  2.03177
#    3 │ 0.792257  2.21901
#    4 │ 0.528828  2.94721
#    5 │ 0.764107  2.64177
